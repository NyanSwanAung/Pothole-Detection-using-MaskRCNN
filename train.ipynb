# %% [markdown]
# <a href="https://colab.research.google.com/github/NyanSwanAung/Pothole-Detection-using-MaskRCNN/blob/main/train.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <h2 align=center> <b>MaskRCNN using Tensorflow Object Detection API (TF Version 2) </h2>

# %% [markdown]
# Using pre-trained model to identify potholes in live webcam and videos. The model was trained on [COCO2017](https://cocodataset.org/) and fine-tuned with pothole dataset from this [repo](https://github.com/SamdenLepcha/Pothole-Detection-With-Mask-R-CNN/tree/master/place_in_object_detection/images).
#
# This pre-trained model is taken from [TensorFlow2 Object Detection Model Zoo](https://github.com/tensorflow/models/blob/master/research/object_detection/g3doc/tf2_detection_zoo.md)

# %% [markdown]
# ## Prepare prerequisite

# %%
#@title Download pretrained model from model zoo
import os
from IPython.display import clear_output

# Download using wget
# !wget http://download.tensorflow.org/models/object_detection/tf2/20200711/mask_rcnn_inception_resnet_v2_1024x1024_coco17_gpu-8.tar.gz

# Extract downloaded tar file 
# !tar -xf mask_rcnn_inception_resnet_v2_1024x1024_coco17_gpu-8.tar.gz

os.mkdir('pre-trained-models')

# Rename extracted folder to pretrained-model
# !mv mask_rcnn_inception_resnet_v2_1024x1024_coco17_gpu-8 pre-trained-models

clear_output()

# %%
#@title Install TensorFlow Object Detection API
# Clone the tensorflow models repository
# !git clone --depth 1 https://github.com/tensorflow/models

# # API Installation 
# !sudo apt install -y protobuf-compiler
# %cd models/research
# !protoc object_detection/protos/*.proto --python_out=.
# !cp object_detection/packages/tf2/setup.py .
# !python -m pip install .

# %cd ~/../content
clear_output()

# %%
#@title Import dependencies
import tensorflow as tf
from object_detection.utils import config_util
from object_detection.protos import pipeline_pb2
from google.protobuf import text_format

from object_detection.utils import ops as utils_ops
from object_detection.utils import label_map_util
from object_detection.utils import visualization_utils as vis_util
from object_detection.builders import model_builder

# patch tf1 into `utils.ops`
utils_ops.tf = tf.compat.v1

import numpy as np
from PIL import Image
from IPython.display import display, Javascript, HTML

import os
import sys
import pathlib
from collections import defaultdict
from io import StringIO
from IPython.display import display

# %% [markdown]
# ### Pothole Dataset

# %%
#@title Download raw pothole dataset from github
# !apt install subversion
# !svn checkout https://github.com/SamdenLepcha/Pothole-Detection-With-Mask-R-CNN/trunk/place_in_object_detection/images
clear_output()

# %%
#@title Download TF Record 
# download train.record
# !wget https://raw.githubusercontent.com/SamdenLepcha/Pothole-Detection-With-Mask-R-CNN/master/place_in_object_detection/train.record

# download test.record
# !wget https://raw.githubusercontent.com/SamdenLepcha/Pothole-Detection-With-Mask-R-CNN/master/place_in_object_detection/test.record

# download label map
# !wget https://raw.githubusercontent.com/SamdenLepcha/Pothole-Detection-With-Mask-R-CNN/master/place_in_object_detection/training/label.pbtxt

clear_output()

# Remove unnecessary folders
# !rm -r sample_data
# !rm -f mask_rcnn_inception_resnet_v2_1024x1024_coco17_gpu-8.tar.gz

# %%
#@title Make workspace

# %cd ~/../content
os.mkdir('workspace')
os.mkdir('workspace/models')
os.mkdir('workspace/models/my_maskrcnn')

# %cd ~/../content
os.mkdir('annotations')
# !mv train.record label.pbtxt -t annotations 
# !mv test.record valid.record
# !mv valid.record -t annotations
# !mv annotations pre-trained-models -t workspace
# !cp /content/workspace/pre-trained-models/mask_rcnn_inception_resnet_v2_1024x1024_coco17_gpu-8/pipeline.config workspace/models/my_maskrcnn 

clear_output()

# %% [markdown]
# ## Setup Paths

# %%
WORKSPACE_PATH = 'workspace'
APIMODEL_PATH = 'models'

ANNOTATION_PATH = WORKSPACE_PATH+'/annotations'

MODEL_PATH = WORKSPACE_PATH+'/models'
PRETRAINED_MODEL_PATH = WORKSPACE_PATH+'/pre-trained-models'

CUSTOM_MODEL_NAME = 'my_maskrcnn'

CONFIG_PATH = MODEL_PATH+'/' + CUSTOM_MODEL_NAME + '/pipeline.config'
CHECKPOINT_PATH = MODEL_PATH+'/' + CUSTOM_MODEL_NAME + '/'

print(CHECKPOINT_PATH )
# Out:
# workspace/models/my_maskrcnn/

# %% [markdown]
# ## Config for fine tuning dataset

# %%
#@title Download updated config from official repo

# %cd /content/workspace/models/my_maskrcnn
# !wget https://raw.githubusercontent.com/tensorflow/models/master/research/object_detection/configs/tf2/mask_rcnn_inception_resnet_v2_1024x1024_coco17_gpu-8.config
# !mv mask_rcnn_inception_resnet_v2_1024x1024_coco17_gpu-8.config pipeline.config
# %cd ~/../content

clear_output()

# %%
# Load config file
config = config_util.get_configs_from_pipeline_file(CONFIG_PATH)

# %%
# Read config file and allow to rewrite access 
pipeline_config = pipeline_pb2.TrainEvalPipelineConfig()
with tf.io.gfile.GFile(CONFIG_PATH, "r") as f:
  proto_str = f.read()
  text_format.Merge(proto_str, pipeline_config)

# %%
# Rewriting 

# Hyperparameters 
pipeline_config.model.faster_rcnn.num_classes = 1
pipeline_config.train_config.batch_size = 1
pipeline_config.model.faster_rcnn.image_resizer.fixed_shape_resizer.height = 512
pipeline_config.model.faster_rcnn.image_resizer.fixed_shape_resizer.width = 512
pipeline_config.train_config.num_steps = 3000

# pre-trained model's checkpoint path
pipeline_config.train_config.fine_tune_checkpoint = PRETRAINED_MODEL_PATH+'/mask_rcnn_inception_resnet_v2_1024x1024_coco17_gpu-8/checkpoint/ckpt-0'

# pre-trained model's checkpoint type
pipeline_config.train_config.fine_tune_checkpoint_type = "detection"

# Train label map path and record path 
pipeline_config.train_input_reader.label_map_path= ANNOTATION_PATH + '/label.pbtxt'
pipeline_config.train_input_reader.tf_record_input_reader.input_path[:] = [ANNOTATION_PATH + '/train.record']

# Valid label map path and record path
pipeline_config.eval_input_reader[0].label_map_path = ANNOTATION_PATH + '/label.pbtxt'
pipeline_config.eval_input_reader[0].tf_record_input_reader.input_path[:] = [ANNOTATION_PATH + '/valid.record']

# Shuffle valid dataset
pipeline_config.eval_input_reader[0].shuffle = True

# %%
config_text = text_format.MessageToString(pipeline_config)                                                                                                                                                                                                        
with tf.io.gfile.GFile(CONFIG_PATH, "wb") as f:                                                                                                                                                                                                                     
    f.write(config_text)

# %% [markdown]
# ## Train model

# %%
# To see available arguments
# !python models/research/object_detection/model_main_tf2.py --help

# %%
# Run Train Script 
# !python models/research/object_detection/model_main_tf2.py \
  --model_dir={CHECKPOINT_PATH} \
  --pipeline_config_path=workspace/models/{CUSTOM_MODEL_NAME}/pipeline.config \
  --alsologtostderr \
  --checkpoint_every_n=1000
# Out:
# 2021-06-09 07:55:58.147350: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# 2021-06-09 07:56:00.164186: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcuda.so.1
# 2021-06-09 07:56:00.192367: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-06-09 07:56:00.192967: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla T4 computeCapability: 7.5
# coreClock: 1.59GHz coreCount: 40 deviceMemorySize: 14.75GiB deviceMemoryBandwidth: 298.08GiB/s
# 2021-06-09 07:56:00.193029: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# 2021-06-09 07:56:00.195918: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublas.so.11
# 2021-06-09 07:56:00.196024: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublasLt.so.11
# 2021-06-09 07:56:00.197697: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcufft.so.10
# 2021-06-09 07:56:00.198071: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcurand.so.10
# 2021-06-09 07:56:00.200061: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcusolver.so.10
# 2021-06-09 07:56:00.200697: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcusparse.so.11
# 2021-06-09 07:56:00.200883: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudnn.so.8
# 2021-06-09 07:56:00.201013: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-06-09 07:56:00.201627: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-06-09 07:56:00.202181: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1871] Adding visible gpu devices: 0
# 2021-06-09 07:56:00.202787: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-06-09 07:56:00.203369: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla T4 computeCapability: 7.5
# coreClock: 1.59GHz coreCount: 40 deviceMemorySize: 14.75GiB deviceMemoryBandwidth: 298.08GiB/s
# 2021-06-09 07:56:00.203458: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-06-09 07:56:00.204061: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-06-09 07:56:00.204588: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1871] Adding visible gpu devices: 0
# 2021-06-09 07:56:00.204643: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# 2021-06-09 07:56:00.846648: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2021-06-09 07:56:00.846700: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]      0
# 2021-06-09 07:56:00.846717: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 0:   N
# 2021-06-09 07:56:00.846911: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-06-09 07:56:00.847595: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-06-09 07:56:00.848213: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-06-09 07:56:00.848741: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2021-06-09 07:56:00.848790: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1418] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 13837 MB memory) -> physical GPU (device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5)
# WARNING:tensorflow:Collective ops is not configured at program startup. Some performance features may not be enabled.
# W0609 07:56:00.850589 140532679501696 mirrored_strategy.py:379] Collective ops is not configured at program startup. Some performance features may not be enabled.
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0',)
# I0609 07:56:00.853522 140532679501696 mirrored_strategy.py:369] Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0',)
# INFO:tensorflow:Maybe overwriting train_steps: None
# I0609 07:56:00.857074 140532679501696 config_util.py:552] Maybe overwriting train_steps: None
# INFO:tensorflow:Maybe overwriting use_bfloat16: False
# I0609 07:56:00.857213 140532679501696 config_util.py:552] Maybe overwriting use_bfloat16: False
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/object_detection/model_lib_v2.py:558: StrategyBase.experimental_distribute_datasets_from_function (from tensorflow.python.distribute.distribute_lib) is deprecated and will be removed in a future version.
# Instructions for updating:
# rename to distribute_datasets_from_function
# W0609 07:56:00.886100 140532679501696 deprecation.py:336] From /usr/local/lib/python3.7/dist-packages/object_detection/model_lib_v2.py:558: StrategyBase.experimental_distribute_datasets_from_function (from tensorflow.python.distribute.distribute_lib) is deprecated and will be removed in a future version.
# Instructions for updating:
# rename to distribute_datasets_from_function
# INFO:tensorflow:Reading unweighted datasets: ['workspace/annotations/train.record']
# I0609 07:56:00.889635 140532679501696 dataset_builder.py:163] Reading unweighted datasets: ['workspace/annotations/train.record']
# INFO:tensorflow:Reading record datasets for input file: ['workspace/annotations/train.record']
# I0609 07:56:00.889865 140532679501696 dataset_builder.py:80] Reading record datasets for input file: ['workspace/annotations/train.record']
# INFO:tensorflow:Number of filenames to read: 1
# I0609 07:56:00.889971 140532679501696 dataset_builder.py:81] Number of filenames to read: 1
# WARNING:tensorflow:num_readers has been reduced to 1 to match input file shards.
# W0609 07:56:00.890069 140532679501696 dataset_builder.py:88] num_readers has been reduced to 1 to match input file shards.
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/object_detection/builders/dataset_builder.py:105: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.experimental_deterministic`.
# W0609 07:56:00.903198 140532679501696 deprecation.py:336] From /usr/local/lib/python3.7/dist-packages/object_detection/builders/dataset_builder.py:105: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.experimental_deterministic`.
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/object_detection/builders/dataset_builder.py:237: DatasetV1.map_with_legacy_function (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map()
# W0609 07:56:00.942946 140532679501696 deprecation.py:336] From /usr/local/lib/python3.7/dist-packages/object_detection/builders/dataset_builder.py:237: DatasetV1.map_with_legacy_function (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map()
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/autograph/impl/api.py:463: calling map_fn (from tensorflow.python.ops.map_fn) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Use fn_output_signature instead
# W0609 07:56:02.578504 140532679501696 deprecation.py:534] From /usr/local/lib/python3.7/dist-packages/tensorflow/python/autograph/impl/api.py:463: calling map_fn (from tensorflow.python.ops.map_fn) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Use fn_output_signature instead
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:206: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# W0609 07:56:08.250093 140532679501696 deprecation.py:336] From /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:206: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/autograph/impl/api.py:464: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# W0609 07:56:11.196303 140532679501696 deprecation.py:336] From /usr/local/lib/python3.7/dist-packages/tensorflow/python/autograph/impl/api.py:464: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# 2021-06-09 07:56:14.015460: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:176] None of the MLIR Optimization Passes are enabled (registered 2)
# 2021-06-09 07:56:14.027204: I tensorflow/core/platform/profile_utils/cpu_utils.cc:114] CPU Frequency: 2199995000 Hz
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/backend.py:435: UserWarning: `tf.keras.backend.set_learning_phase` is deprecated and will be removed after 2020-10-11. To update it, simply pass a True/False value to the `training` argument of the `__call__` method of your layer or model.
#   warnings.warn('`tf.keras.backend.set_learning_phase` is deprecated and '
# INFO:tensorflow:depth of additional conv before box predictor: 0
# I0609 07:56:26.301929 140529172416256 convolutional_keras_box_predictor.py:154] depth of additional conv before box predictor: 0
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:206: calling crop_and_resize_v1 (from tensorflow.python.ops.image_ops_impl) with box_ind is deprecated and will be removed in a future version.
# Instructions for updating:
# box_ind is deprecated, use box_indices instead
# W0609 07:56:31.917163 140529172416256 deprecation.py:534] From /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:206: calling crop_and_resize_v1 (from tensorflow.python.ops.image_ops_impl) with box_ind is deprecated and will be removed in a future version.
# Instructions for updating:
# box_ind is deprecated, use box_indices instead
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/autograph/impl/api.py:464: Tensor.experimental_ref (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use ref() instead.
# W0609 07:56:32.417873 140529172416256 deprecation.py:336] From /usr/local/lib/python3.7/dist-packages/tensorflow/python/autograph/impl/api.py:464: Tensor.experimental_ref (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use ref() instead.
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:206: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See `tf.nn.softmax_cross_entropy_with_logits_v2`.
#
# W0609 07:56:39.872282 140529172416256 deprecation.py:336] From /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:206: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See `tf.nn.softmax_cross_entropy_with_logits_v2`.
#
# 2021-06-09 07:56:56.836784: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudnn.so.8
# 2021-06-09 07:56:59.028756: I tensorflow/stream_executor/cuda/cuda_dnn.cc:359] Loaded cuDNN version 8004
# 2021-06-09 07:57:23.263164: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublas.so.11
# 2021-06-09 07:57:25.774929: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublasLt.so.11
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0609 07:57:44.701291 140532679501696 cross_device_ops.py:621] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0609 07:57:44.702480 140532679501696 cross_device_ops.py:621] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0609 07:57:44.704180 140532679501696 cross_device_ops.py:621] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0609 07:57:44.705067 140532679501696 cross_device_ops.py:621] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0609 07:57:44.706769 140532679501696 cross_device_ops.py:621] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0609 07:57:44.707612 140532679501696 cross_device_ops.py:621] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0609 07:57:44.709200 140532679501696 cross_device_ops.py:621] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0609 07:57:44.710225 140532679501696 cross_device_ops.py:621] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0609 07:57:44.712153 140532679501696 cross_device_ops.py:621] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0609 07:57:44.713013 140532679501696 cross_device_ops.py:621] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/deprecation.py:602: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Use fn_output_signature instead
# W0609 07:57:46.301597 140529180808960 deprecation.py:534] From /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/deprecation.py:602: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Use fn_output_signature instead
# INFO:tensorflow:Step 100 per-step time 1.375s
# I0609 08:00:03.346771 140532679501696 model_lib_v2.py:700] Step 100 per-step time 1.375s
# INFO:tensorflow:{'Loss/BoxClassifierLoss/classification_loss': 0.018416926,
#  'Loss/BoxClassifierLoss/localization_loss': 0.0,
#  'Loss/BoxClassifierLoss/mask_loss': 0.0,
#  'Loss/RPNLoss/localization_loss': 0.083752826,
#  'Loss/RPNLoss/objectness_loss': 0.66165924,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.763829,
#  'learning_rate': 0.00016000001}
# I0609 08:00:03.347213 140532679501696 model_lib_v2.py:701] {'Loss/BoxClassifierLoss/classification_loss': 0.018416926,
#  'Loss/BoxClassifierLoss/localization_loss': 0.0,
#  'Loss/BoxClassifierLoss/mask_loss': 0.0,
#  'Loss/RPNLoss/localization_loss': 0.083752826,
#  'Loss/RPNLoss/objectness_loss': 0.66165924,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.763829,
#  'learning_rate': 0.00016000001}
# INFO:tensorflow:Step 200 per-step time 0.620s
# I0609 08:01:05.354472 140532679501696 model_lib_v2.py:700] Step 200 per-step time 0.620s
# INFO:tensorflow:{'Loss/BoxClassifierLoss/classification_loss': 0.004659025,
#  'Loss/BoxClassifierLoss/localization_loss': 0.0,
#  'Loss/BoxClassifierLoss/mask_loss': 0.0,
#  'Loss/RPNLoss/localization_loss': 0.031881552,
#  'Loss/RPNLoss/objectness_loss': 0.5162662,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.5528068,
#  'learning_rate': 0.00032000002}
# I0609 08:01:05.354819 140532679501696 model_lib_v2.py:701] {'Loss/BoxClassifierLoss/classification_loss': 0.004659025,
#  'Loss/BoxClassifierLoss/localization_loss': 0.0,
#  'Loss/BoxClassifierLoss/mask_loss': 0.0,
#  'Loss/RPNLoss/localization_loss': 0.031881552,
#  'Loss/RPNLoss/objectness_loss': 0.5162662,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.5528068,
#  'learning_rate': 0.00032000002}
# INFO:tensorflow:Step 300 per-step time 0.650s
# I0609 08:02:10.313987 140532679501696 model_lib_v2.py:700] Step 300 per-step time 0.650s
# INFO:tensorflow:{'Loss/BoxClassifierLoss/classification_loss': 0.00047804668,
#  'Loss/BoxClassifierLoss/localization_loss': 0.0,
#  'Loss/BoxClassifierLoss/mask_loss': 0.0,
#  'Loss/RPNLoss/localization_loss': 0.28589693,
#  'Loss/RPNLoss/objectness_loss': 0.100062564,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.38643754,
#  'learning_rate': 0.00048000005}
# I0609 08:02:10.314377 140532679501696 model_lib_v2.py:701] {'Loss/BoxClassifierLoss/classification_loss': 0.00047804668,
#  'Loss/BoxClassifierLoss/localization_loss': 0.0,
#  'Loss/BoxClassifierLoss/mask_loss': 0.0,
#  'Loss/RPNLoss/localization_loss': 0.28589693,
#  'Loss/RPNLoss/objectness_loss': 0.100062564,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.38643754,
#  'learning_rate': 0.00048000005}
# INFO:tensorflow:Step 400 per-step time 0.647s
# I0609 08:03:15.056061 140532679501696 model_lib_v2.py:700] Step 400 per-step time 0.647s
# INFO:tensorflow:{'Loss/BoxClassifierLoss/classification_loss': 7.6292126e-06,
#  'Loss/BoxClassifierLoss/localization_loss': 0.0,
#  'Loss/BoxClassifierLoss/mask_loss': 0.0,
#  'Loss/RPNLoss/localization_loss': 0.0916588,
#  'Loss/RPNLoss/objectness_loss': 0.04267502,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.13434145,
#  'learning_rate': 0.00064000004}
# I0609 08:03:15.056435 140532679501696 model_lib_v2.py:701] {'Loss/BoxClassifierLoss/classification_loss': 7.6292126e-06,
#  'Loss/BoxClassifierLoss/localization_loss': 0.0,
#  'Loss/BoxClassifierLoss/mask_loss': 0.0,
#  'Loss/RPNLoss/localization_loss': 0.0916588,
#  'Loss/RPNLoss/objectness_loss': 0.04267502,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.13434145,
#  'learning_rate': 0.00064000004}
# INFO:tensorflow:Step 500 per-step time 0.644s
# I0609 08:04:19.449005 140532679501696 model_lib_v2.py:700] Step 500 per-step time 0.644s
# INFO:tensorflow:{'Loss/BoxClassifierLoss/classification_loss': 5.5731514e-05,
#  'Loss/BoxClassifierLoss/localization_loss': 0.0,
#  'Loss/BoxClassifierLoss/mask_loss': 0.0,
#  'Loss/RPNLoss/localization_loss': 0.042595454,
#  'Loss/RPNLoss/objectness_loss': 0.023998447,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.06664963,
#  'learning_rate': 0.00080000004}
# I0609 08:04:19.449402 140532679501696 model_lib_v2.py:701] {'Loss/BoxClassifierLoss/classification_loss': 5.5731514e-05,
#  'Loss/BoxClassifierLoss/localization_loss': 0.0,
#  'Loss/BoxClassifierLoss/mask_loss': 0.0,
#  'Loss/RPNLoss/localization_loss': 0.042595454,
#  'Loss/RPNLoss/objectness_loss': 0.023998447,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.06664963,
#  'learning_rate': 0.00080000004}
# INFO:tensorflow:Step 600 per-step time 0.646s
# I0609 08:05:24.035216 140532679501696 model_lib_v2.py:700] Step 600 per-step time 0.646s
# INFO:tensorflow:{'Loss/BoxClassifierLoss/classification_loss': 0.0011508309,
#  'Loss/BoxClassifierLoss/localization_loss': 0.0,
#  'Loss/BoxClassifierLoss/mask_loss': 0.0,
#  'Loss/RPNLoss/localization_loss': 0.050024457,
#  'Loss/RPNLoss/objectness_loss': 0.02288464,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.07405993,
#  'learning_rate': 0.0009600001}
# I0609 08:05:24.035567 140532679501696 model_lib_v2.py:701] {'Loss/BoxClassifierLoss/classification_loss': 0.0011508309,
#  'Loss/BoxClassifierLoss/localization_loss': 0.0,
#  'Loss/BoxClassifierLoss/mask_loss': 0.0,
#  'Loss/RPNLoss/localization_loss': 0.050024457,
#  'Loss/RPNLoss/objectness_loss': 0.02288464,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.07405993,
#  'learning_rate': 0.0009600001}
# INFO:tensorflow:Step 700 per-step time 0.644s
# I0609 08:06:28.462025 140532679501696 model_lib_v2.py:700] Step 700 per-step time 0.644s
# INFO:tensorflow:{'Loss/BoxClassifierLoss/classification_loss': 0.0070218393,
#  'Loss/BoxClassifierLoss/localization_loss': 0.0,
#  'Loss/BoxClassifierLoss/mask_loss': 0.0,
#  'Loss/RPNLoss/localization_loss': 0.1349993,
#  'Loss/RPNLoss/objectness_loss': 0.14699367,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.28901482,
#  'learning_rate': 0.0011200001}
# I0609 08:06:28.462400 140532679501696 model_lib_v2.py:701] {'Loss/BoxClassifierLoss/classification_loss': 0.0070218393,
#  'Loss/BoxClassifierLoss/localization_loss': 0.0,
#  'Loss/BoxClassifierLoss/mask_loss': 0.0,
#  'Loss/RPNLoss/localization_loss': 0.1349993,
#  'Loss/RPNLoss/objectness_loss': 0.14699367,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.28901482,
#  'learning_rate': 0.0011200001}
# INFO:tensorflow:Step 800 per-step time 0.644s
# I0609 08:07:32.893734 140532679501696 model_lib_v2.py:700] Step 800 per-step time 0.644s
# INFO:tensorflow:{'Loss/BoxClassifierLoss/classification_loss': 0.076903,
#  'Loss/BoxClassifierLoss/localization_loss': 0.12020874,
#  'Loss/BoxClassifierLoss/mask_loss': 2.8203833,
#  'Loss/RPNLoss/localization_loss': 0.011487927,
#  'Loss/RPNLoss/objectness_loss': 0.01340346,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 3.0423865,
#  'learning_rate': 0.0012800001}
# I0609 08:07:32.894134 140532679501696 model_lib_v2.py:701] {'Loss/BoxClassifierLoss/classification_loss': 0.076903,
#  'Loss/BoxClassifierLoss/localization_loss': 0.12020874,
#  'Loss/BoxClassifierLoss/mask_loss': 2.8203833,
#  'Loss/RPNLoss/localization_loss': 0.011487927,
#  'Loss/RPNLoss/objectness_loss': 0.01340346,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 3.0423865,
#  'learning_rate': 0.0012800001}
# INFO:tensorflow:Step 900 per-step time 0.642s
# I0609 08:08:37.142923 140532679501696 model_lib_v2.py:700] Step 900 per-step time 0.642s
# INFO:tensorflow:{'Loss/BoxClassifierLoss/classification_loss': 0.0010195163,
#  'Loss/BoxClassifierLoss/localization_loss': 0.0,
#  'Loss/BoxClassifierLoss/mask_loss': 0.0,
#  'Loss/RPNLoss/localization_loss': 0.11666621,
#  'Loss/RPNLoss/objectness_loss': 0.028243903,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.14592963,
#  'learning_rate': 0.0014400001}
# I0609 08:08:37.143295 140532679501696 model_lib_v2.py:701] {'Loss/BoxClassifierLoss/classification_loss': 0.0010195163,
#  'Loss/BoxClassifierLoss/localization_loss': 0.0,
#  'Loss/BoxClassifierLoss/mask_loss': 0.0,
#  'Loss/RPNLoss/localization_loss': 0.11666621,
#  'Loss/RPNLoss/objectness_loss': 0.028243903,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.14592963,
#  'learning_rate': 0.0014400001}
# INFO:tensorflow:Step 1000 per-step time 0.644s
# I0609 08:09:41.566437 140532679501696 model_lib_v2.py:700] Step 1000 per-step time 0.644s
# INFO:tensorflow:{'Loss/BoxClassifierLoss/classification_loss': 0.10543981,
#  'Loss/BoxClassifierLoss/localization_loss': 0.291739,
#  'Loss/BoxClassifierLoss/mask_loss': 2.5432916,
#  'Loss/RPNLoss/localization_loss': 0.09127694,
#  'Loss/RPNLoss/objectness_loss': 0.043271005,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 3.0750184,
#  'learning_rate': 0.0016000001}
# I0609 08:09:41.566820 140532679501696 model_lib_v2.py:701] {'Loss/BoxClassifierLoss/classification_loss': 0.10543981,
#  'Loss/BoxClassifierLoss/localization_loss': 0.291739,
#  'Loss/BoxClassifierLoss/mask_loss': 2.5432916,
#  'Loss/RPNLoss/localization_loss': 0.09127694,
#  'Loss/RPNLoss/objectness_loss': 0.043271005,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 3.0750184,
#  'learning_rate': 0.0016000001}
# INFO:tensorflow:Step 1100 per-step time 0.675s
# I0609 08:10:49.070058 140532679501696 model_lib_v2.py:700] Step 1100 per-step time 0.675s
# INFO:tensorflow:{'Loss/BoxClassifierLoss/classification_loss': 0.010564886,
#  'Loss/BoxClassifierLoss/localization_loss': 0.0,
#  'Loss/BoxClassifierLoss/mask_loss': 0.0,
#  'Loss/RPNLoss/localization_loss': 0.053231362,
#  'Loss/RPNLoss/objectness_loss': 0.045835797,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.109632045,
#  'learning_rate': 0.0017600001}
# I0609 08:10:49.070427 140532679501696 model_lib_v2.py:701] {'Loss/BoxClassifierLoss/classification_loss': 0.010564886,
#  'Loss/BoxClassifierLoss/localization_loss': 0.0,
#  'Loss/BoxClassifierLoss/mask_loss': 0.0,
#  'Loss/RPNLoss/localization_loss': 0.053231362,
#  'Loss/RPNLoss/objectness_loss': 0.045835797,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.109632045,
#  'learning_rate': 0.0017600001}
# INFO:tensorflow:Step 1200 per-step time 0.644s
# I0609 08:11:53.435450 140532679501696 model_lib_v2.py:700] Step 1200 per-step time 0.644s
# INFO:tensorflow:{'Loss/BoxClassifierLoss/classification_loss': 0.16553083,
#  'Loss/BoxClassifierLoss/localization_loss': 0.4141386,
#  'Loss/BoxClassifierLoss/mask_loss': 2.7915778,
#  'Loss/RPNLoss/localization_loss': 0.050664872,
#  'Loss/RPNLoss/objectness_loss': 0.046906214,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 3.4688184,
#  'learning_rate': 0.0019200002}
# I0609 08:11:53.435832 140532679501696 model_lib_v2.py:701] {'Loss/BoxClassifierLoss/classification_loss': 0.16553083,
#  'Loss/BoxClassifierLoss/localization_loss': 0.4141386,
#  'Loss/BoxClassifierLoss/mask_loss': 2.7915778,
#  'Loss/RPNLoss/localization_loss': 0.050664872,
#  'Loss/RPNLoss/objectness_loss': 0.046906214,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 3.4688184,
#  'learning_rate': 0.0019200002}
# INFO:tensorflow:Step 1300 per-step time 0.649s
# I0609 08:12:58.346616 140532679501696 model_lib_v2.py:700] Step 1300 per-step time 0.649s
# INFO:tensorflow:{'Loss/BoxClassifierLoss/classification_loss': 0.029880408,
#  'Loss/BoxClassifierLoss/localization_loss': 0.0,
#  'Loss/BoxClassifierLoss/mask_loss': 0.0,
#  'Loss/RPNLoss/localization_loss': 0.023530396,
#  'Loss/RPNLoss/objectness_loss': 0.016205732,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.069616534,
#  'learning_rate': 0.0020800002}
# I0609 08:12:58.346970 140532679501696 model_lib_v2.py:701] {'Loss/BoxClassifierLoss/classification_loss': 0.029880408,
#  'Loss/BoxClassifierLoss/localization_loss': 0.0,
#  'Loss/BoxClassifierLoss/mask_loss': 0.0,
#  'Loss/RPNLoss/localization_loss': 0.023530396,
#  'Loss/RPNLoss/objectness_loss': 0.016205732,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.069616534,
#  'learning_rate': 0.0020800002}
# INFO:tensorflow:Step 1400 per-step time 0.646s
# I0609 08:14:02.957863 140532679501696 model_lib_v2.py:700] Step 1400 per-step time 0.646s
# INFO:tensorflow:{'Loss/BoxClassifierLoss/classification_loss': 0.029882217,
#  'Loss/BoxClassifierLoss/localization_loss': 0.05884791,
#  'Loss/BoxClassifierLoss/mask_loss': 1.5586342,
#  'Loss/RPNLoss/localization_loss': 0.0081773,
#  'Loss/RPNLoss/objectness_loss': 0.016185237,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 1.6717268,
#  'learning_rate': 0.0022400003}
# I0609 08:14:02.958299 140532679501696 model_lib_v2.py:701] {'Loss/BoxClassifierLoss/classification_loss': 0.029882217,
#  'Loss/BoxClassifierLoss/localization_loss': 0.05884791,
#  'Loss/BoxClassifierLoss/mask_loss': 1.5586342,
#  'Loss/RPNLoss/localization_loss': 0.0081773,
#  'Loss/RPNLoss/objectness_loss': 0.016185237,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 1.6717268,
#  'learning_rate': 0.0022400003}
# INFO:tensorflow:Step 1500 per-step time 0.648s
# I0609 08:15:07.744809 140532679501696 model_lib_v2.py:700] Step 1500 per-step time 0.648s
# INFO:tensorflow:{'Loss/BoxClassifierLoss/classification_loss': 0.010775695,
#  'Loss/BoxClassifierLoss/localization_loss': 0.0,
#  'Loss/BoxClassifierLoss/mask_loss': 0.0,
#  'Loss/RPNLoss/localization_loss': 0.011121232,
#  'Loss/RPNLoss/objectness_loss': 0.01633901,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.038235936,
#  'learning_rate': 0.0024}
# I0609 08:15:07.745174 140532679501696 model_lib_v2.py:701] {'Loss/BoxClassifierLoss/classification_loss': 0.010775695,
#  'Loss/BoxClassifierLoss/localization_loss': 0.0,
#  'Loss/BoxClassifierLoss/mask_loss': 0.0,
#  'Loss/RPNLoss/localization_loss': 0.011121232,
#  'Loss/RPNLoss/objectness_loss': 0.01633901,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.038235936,
#  'learning_rate': 0.0024}
# INFO:tensorflow:Step 1600 per-step time 0.647s
# I0609 08:16:12.469409 140532679501696 model_lib_v2.py:700] Step 1600 per-step time 0.647s
# INFO:tensorflow:{'Loss/BoxClassifierLoss/classification_loss': 0.08719852,
#  'Loss/BoxClassifierLoss/localization_loss': 0.59414595,
#  'Loss/BoxClassifierLoss/mask_loss': 1.6430563,
#  'Loss/RPNLoss/localization_loss': 0.11193396,
#  'Loss/RPNLoss/objectness_loss': 0.123050965,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 2.5593855,
#  'learning_rate': 0.0025600002}
# I0609 08:16:12.469823 140532679501696 model_lib_v2.py:701] {'Loss/BoxClassifierLoss/classification_loss': 0.08719852,
#  'Loss/BoxClassifierLoss/localization_loss': 0.59414595,
#  'Loss/BoxClassifierLoss/mask_loss': 1.6430563,
#  'Loss/RPNLoss/localization_loss': 0.11193396,
#  'Loss/RPNLoss/objectness_loss': 0.123050965,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 2.5593855,
#  'learning_rate': 0.0025600002}
# INFO:tensorflow:Step 1700 per-step time 0.647s
# I0609 08:17:17.198608 140532679501696 model_lib_v2.py:700] Step 1700 per-step time 0.647s
# INFO:tensorflow:{'Loss/BoxClassifierLoss/classification_loss': 0.021485645,
#  'Loss/BoxClassifierLoss/localization_loss': 0.0,
#  'Loss/BoxClassifierLoss/mask_loss': 0.0,
#  'Loss/RPNLoss/localization_loss': 0.09210552,
#  'Loss/RPNLoss/objectness_loss': 0.030072939,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.1436641,
#  'learning_rate': 0.0027200002}
# I0609 08:17:17.198959 140532679501696 model_lib_v2.py:701] {'Loss/BoxClassifierLoss/classification_loss': 0.021485645,
#  'Loss/BoxClassifierLoss/localization_loss': 0.0,
#  'Loss/BoxClassifierLoss/mask_loss': 0.0,
#  'Loss/RPNLoss/localization_loss': 0.09210552,
#  'Loss/RPNLoss/objectness_loss': 0.030072939,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.1436641,
#  'learning_rate': 0.0027200002}
# INFO:tensorflow:Step 1800 per-step time 0.647s
# I0609 08:18:21.879955 140532679501696 model_lib_v2.py:700] Step 1800 per-step time 0.647s
# INFO:tensorflow:{'Loss/BoxClassifierLoss/classification_loss': 0.050062004,
#  'Loss/BoxClassifierLoss/localization_loss': 0.03725775,
#  'Loss/BoxClassifierLoss/mask_loss': 1.7939812,
#  'Loss/RPNLoss/localization_loss': 0.16576329,
#  'Loss/RPNLoss/objectness_loss': 0.038415052,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 2.0854793,
#  'learning_rate': 0.0028800003}
# I0609 08:18:21.880373 140532679501696 model_lib_v2.py:701] {'Loss/BoxClassifierLoss/classification_loss': 0.050062004,
#  'Loss/BoxClassifierLoss/localization_loss': 0.03725775,
#  'Loss/BoxClassifierLoss/mask_loss': 1.7939812,
#  'Loss/RPNLoss/localization_loss': 0.16576329,
#  'Loss/RPNLoss/objectness_loss': 0.038415052,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 2.0854793,
#  'learning_rate': 0.0028800003}
# INFO:tensorflow:Step 1900 per-step time 0.645s
# I0609 08:19:26.372941 140532679501696 model_lib_v2.py:700] Step 1900 per-step time 0.645s
# INFO:tensorflow:{'Loss/BoxClassifierLoss/classification_loss': 0.024854122,
#  'Loss/BoxClassifierLoss/localization_loss': 0.044435676,
#  'Loss/BoxClassifierLoss/mask_loss': 1.9918423,
#  'Loss/RPNLoss/localization_loss': 0.032000564,
#  'Loss/RPNLoss/objectness_loss': 0.031206075,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 2.1243386,
#  'learning_rate': 0.0030400003}
# I0609 08:19:26.373326 140532679501696 model_lib_v2.py:701] {'Loss/BoxClassifierLoss/classification_loss': 0.024854122,
#  'Loss/BoxClassifierLoss/localization_loss': 0.044435676,
#  'Loss/BoxClassifierLoss/mask_loss': 1.9918423,
#  'Loss/RPNLoss/localization_loss': 0.032000564,
#  'Loss/RPNLoss/objectness_loss': 0.031206075,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 2.1243386,
#  'learning_rate': 0.0030400003}
# INFO:tensorflow:Step 2000 per-step time 0.646s
# I0609 08:20:30.967466 140532679501696 model_lib_v2.py:700] Step 2000 per-step time 0.646s
# INFO:tensorflow:{'Loss/BoxClassifierLoss/classification_loss': 0.03015613,
#  'Loss/BoxClassifierLoss/localization_loss': 0.0,
#  'Loss/BoxClassifierLoss/mask_loss': 0.0,
#  'Loss/RPNLoss/localization_loss': 0.15697539,
#  'Loss/RPNLoss/objectness_loss': 0.048366085,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.2354976,
#  'learning_rate': 0.0032000002}
# I0609 08:20:30.967822 140532679501696 model_lib_v2.py:701] {'Loss/BoxClassifierLoss/classification_loss': 0.03015613,
#  'Loss/BoxClassifierLoss/localization_loss': 0.0,
#  'Loss/BoxClassifierLoss/mask_loss': 0.0,
#  'Loss/RPNLoss/localization_loss': 0.15697539,
#  'Loss/RPNLoss/objectness_loss': 0.048366085,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.2354976,
#  'learning_rate': 0.0032000002}
# INFO:tensorflow:Step 2100 per-step time 0.677s
# I0609 08:21:38.651666 140532679501696 model_lib_v2.py:700] Step 2100 per-step time 0.677s
# INFO:tensorflow:{'Loss/BoxClassifierLoss/classification_loss': 0.0632015,
#  'Loss/BoxClassifierLoss/localization_loss': 0.17017126,
#  'Loss/BoxClassifierLoss/mask_loss': 1.0747248,
#  'Loss/RPNLoss/localization_loss': 0.100194775,
#  'Loss/RPNLoss/objectness_loss': 0.06379022,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 1.4720826,
#  'learning_rate': 0.0033600002}
# I0609 08:21:38.652057 140532679501696 model_lib_v2.py:701] {'Loss/BoxClassifierLoss/classification_loss': 0.0632015,
#  'Loss/BoxClassifierLoss/localization_loss': 0.17017126,
#  'Loss/BoxClassifierLoss/mask_loss': 1.0747248,
#  'Loss/RPNLoss/localization_loss': 0.100194775,
#  'Loss/RPNLoss/objectness_loss': 0.06379022,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 1.4720826,
#  'learning_rate': 0.0033600002}
# INFO:tensorflow:Step 2200 per-step time 0.647s
# I0609 08:22:43.317497 140532679501696 model_lib_v2.py:700] Step 2200 per-step time 0.647s
# INFO:tensorflow:{'Loss/BoxClassifierLoss/classification_loss': 0.19580463,
#  'Loss/BoxClassifierLoss/localization_loss': 0.34945238,
#  'Loss/BoxClassifierLoss/mask_loss': 1.8053906,
#  'Loss/RPNLoss/localization_loss': 0.08839807,
#  'Loss/RPNLoss/objectness_loss': 0.059676997,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 2.4987223,
#  'learning_rate': 0.0035200003}
# I0609 08:22:43.317848 140532679501696 model_lib_v2.py:701] {'Loss/BoxClassifierLoss/classification_loss': 0.19580463,
#  'Loss/BoxClassifierLoss/localization_loss': 0.34945238,
#  'Loss/BoxClassifierLoss/mask_loss': 1.8053906,
#  'Loss/RPNLoss/localization_loss': 0.08839807,
#  'Loss/RPNLoss/objectness_loss': 0.059676997,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 2.4987223,
#  'learning_rate': 0.0035200003}
# INFO:tensorflow:Step 2300 per-step time 0.646s
# I0609 08:23:47.896217 140532679501696 model_lib_v2.py:700] Step 2300 per-step time 0.646s
# INFO:tensorflow:{'Loss/BoxClassifierLoss/classification_loss': 0.124290064,
#  'Loss/BoxClassifierLoss/localization_loss': 0.14561519,
#  'Loss/BoxClassifierLoss/mask_loss': 2.9125347,
#  'Loss/RPNLoss/localization_loss': 0.18898478,
#  'Loss/RPNLoss/objectness_loss': 0.045447122,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 3.416872,
#  'learning_rate': 0.0036800003}
# I0609 08:23:47.896595 140532679501696 model_lib_v2.py:701] {'Loss/BoxClassifierLoss/classification_loss': 0.124290064,
#  'Loss/BoxClassifierLoss/localization_loss': 0.14561519,
#  'Loss/BoxClassifierLoss/mask_loss': 2.9125347,
#  'Loss/RPNLoss/localization_loss': 0.18898478,
#  'Loss/RPNLoss/objectness_loss': 0.045447122,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 3.416872,
#  'learning_rate': 0.0036800003}
# INFO:tensorflow:Step 2400 per-step time 0.645s
# I0609 08:24:52.422921 140532679501696 model_lib_v2.py:700] Step 2400 per-step time 0.645s
# INFO:tensorflow:{'Loss/BoxClassifierLoss/classification_loss': 0.017378464,
#  'Loss/BoxClassifierLoss/localization_loss': 0.0,
#  'Loss/BoxClassifierLoss/mask_loss': 0.0,
#  'Loss/RPNLoss/localization_loss': 0.033203542,
#  'Loss/RPNLoss/objectness_loss': 0.00942529,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.060007297,
#  'learning_rate': 0.0038400004}
# I0609 08:24:52.423287 140532679501696 model_lib_v2.py:701] {'Loss/BoxClassifierLoss/classification_loss': 0.017378464,
#  'Loss/BoxClassifierLoss/localization_loss': 0.0,
#  'Loss/BoxClassifierLoss/mask_loss': 0.0,
#  'Loss/RPNLoss/localization_loss': 0.033203542,
#  'Loss/RPNLoss/objectness_loss': 0.00942529,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.060007297,
#  'learning_rate': 0.0038400004}
# INFO:tensorflow:Step 2500 per-step time 0.644s
# I0609 08:25:56.800561 140532679501696 model_lib_v2.py:700] Step 2500 per-step time 0.644s
# INFO:tensorflow:{'Loss/BoxClassifierLoss/classification_loss': 0.004425704,
#  'Loss/BoxClassifierLoss/localization_loss': 0.0,
#  'Loss/BoxClassifierLoss/mask_loss': 0.0,
#  'Loss/RPNLoss/localization_loss': 0.051637843,
#  'Loss/RPNLoss/objectness_loss': 0.016464649,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.0725282,
#  'learning_rate': 0.004}
# I0609 08:25:56.800936 140532679501696 model_lib_v2.py:701] {'Loss/BoxClassifierLoss/classification_loss': 0.004425704,
#  'Loss/BoxClassifierLoss/localization_loss': 0.0,
#  'Loss/BoxClassifierLoss/mask_loss': 0.0,
#  'Loss/RPNLoss/localization_loss': 0.051637843,
#  'Loss/RPNLoss/objectness_loss': 0.016464649,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.0725282,
#  'learning_rate': 0.004}
# INFO:tensorflow:Step 2600 per-step time 0.644s
# I0609 08:27:01.200689 140532679501696 model_lib_v2.py:700] Step 2600 per-step time 0.644s
# INFO:tensorflow:{'Loss/BoxClassifierLoss/classification_loss': 0.0019611353,
#  'Loss/BoxClassifierLoss/localization_loss': 0.0,
#  'Loss/BoxClassifierLoss/mask_loss': 0.0,
#  'Loss/RPNLoss/localization_loss': 0.07742062,
#  'Loss/RPNLoss/objectness_loss': 0.021667285,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.10104904,
#  'learning_rate': 0.0041600005}
# I0609 08:27:01.201060 140532679501696 model_lib_v2.py:701] {'Loss/BoxClassifierLoss/classification_loss': 0.0019611353,
#  'Loss/BoxClassifierLoss/localization_loss': 0.0,
#  'Loss/BoxClassifierLoss/mask_loss': 0.0,
#  'Loss/RPNLoss/localization_loss': 0.07742062,
#  'Loss/RPNLoss/objectness_loss': 0.021667285,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.10104904,
#  'learning_rate': 0.0041600005}
# INFO:tensorflow:Step 2700 per-step time 0.647s
# I0609 08:28:05.866000 140532679501696 model_lib_v2.py:700] Step 2700 per-step time 0.647s
# INFO:tensorflow:{'Loss/BoxClassifierLoss/classification_loss': 0.0866755,
#  'Loss/BoxClassifierLoss/localization_loss': 0.2692363,
#  'Loss/BoxClassifierLoss/mask_loss': 1.2015342,
#  'Loss/RPNLoss/localization_loss': 0.13283467,
#  'Loss/RPNLoss/objectness_loss': 0.038548604,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 1.7288293,
#  'learning_rate': 0.0043200003}
# I0609 08:28:05.866380 140532679501696 model_lib_v2.py:701] {'Loss/BoxClassifierLoss/classification_loss': 0.0866755,
#  'Loss/BoxClassifierLoss/localization_loss': 0.2692363,
#  'Loss/BoxClassifierLoss/mask_loss': 1.2015342,
#  'Loss/RPNLoss/localization_loss': 0.13283467,
#  'Loss/RPNLoss/objectness_loss': 0.038548604,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 1.7288293,
#  'learning_rate': 0.0043200003}
# INFO:tensorflow:Step 2800 per-step time 0.645s
# I0609 08:29:10.393426 140532679501696 model_lib_v2.py:700] Step 2800 per-step time 0.645s
# INFO:tensorflow:{'Loss/BoxClassifierLoss/classification_loss': 3.7513524e-05,
#  'Loss/BoxClassifierLoss/localization_loss': 0.0,
#  'Loss/BoxClassifierLoss/mask_loss': 0.0,
#  'Loss/RPNLoss/localization_loss': 0.08650217,
#  'Loss/RPNLoss/objectness_loss': 0.01835577,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.10489546,
#  'learning_rate': 0.0044800006}
# I0609 08:29:10.393765 140532679501696 model_lib_v2.py:701] {'Loss/BoxClassifierLoss/classification_loss': 3.7513524e-05,
#  'Loss/BoxClassifierLoss/localization_loss': 0.0,
#  'Loss/BoxClassifierLoss/mask_loss': 0.0,
#  'Loss/RPNLoss/localization_loss': 0.08650217,
#  'Loss/RPNLoss/objectness_loss': 0.01835577,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.10489546,
#  'learning_rate': 0.0044800006}
# INFO:tensorflow:Step 2900 per-step time 0.644s
# I0609 08:30:14.834301 140532679501696 model_lib_v2.py:700] Step 2900 per-step time 0.644s
# INFO:tensorflow:{'Loss/BoxClassifierLoss/classification_loss': 0.00050119206,
#  'Loss/BoxClassifierLoss/localization_loss': 0.0,
#  'Loss/BoxClassifierLoss/mask_loss': 0.0,
#  'Loss/RPNLoss/localization_loss': 0.15339437,
#  'Loss/RPNLoss/objectness_loss': 0.028965993,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.18286155,
#  'learning_rate': 0.0046400004}
# I0609 08:30:14.834666 140532679501696 model_lib_v2.py:701] {'Loss/BoxClassifierLoss/classification_loss': 0.00050119206,
#  'Loss/BoxClassifierLoss/localization_loss': 0.0,
#  'Loss/BoxClassifierLoss/mask_loss': 0.0,
#  'Loss/RPNLoss/localization_loss': 0.15339437,
#  'Loss/RPNLoss/objectness_loss': 0.028965993,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.18286155,
#  'learning_rate': 0.0046400004}
# INFO:tensorflow:Step 3000 per-step time 0.648s
# I0609 08:31:19.611161 140532679501696 model_lib_v2.py:700] Step 3000 per-step time 0.648s
# INFO:tensorflow:{'Loss/BoxClassifierLoss/classification_loss': 0.019649796,
#  'Loss/BoxClassifierLoss/localization_loss': 0.025241787,
#  'Loss/BoxClassifierLoss/mask_loss': 1.8854611,
#  'Loss/RPNLoss/localization_loss': 0.17313561,
#  'Loss/RPNLoss/objectness_loss': 0.027059287,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 2.1305475,
#  'learning_rate': 0.0048}
# I0609 08:31:19.611537 140532679501696 model_lib_v2.py:701] {'Loss/BoxClassifierLoss/classification_loss': 0.019649796,
#  'Loss/BoxClassifierLoss/localization_loss': 0.025241787,
#  'Loss/BoxClassifierLoss/mask_loss': 1.8854611,
#  'Loss/RPNLoss/localization_loss': 0.17313561,
#  'Loss/RPNLoss/objectness_loss': 0.027059287,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 2.1305475,
#  'learning_rate': 0.0048}

# %%
# Run evaluation script 
# !python models/research/object_detection/model_main_tf2.py \
  --model_dir={CHECKPOINT_PATH} \
  --pipeline_config_path=workspace/models/{CUSTOM_MODEL_NAME}/pipeline.config \
  --checkpoint_dir={CHECKPOINT_PATH}

# %% [markdown]
# ## Export model to inference graph

# %%
output_directory = CHECKPOINT_PATH + 'inference_graph'

# !python models/research/object_detection/exporter_main_v2.py \
    --trained_checkpoint_dir {CHECKPOINT_PATH} \
    --output_directory {output_directory} \
    --pipeline_config_path {CONFIG_PATH}
# Out:
# 2021-06-09 09:00:56.720339: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# 2021-06-09 09:00:59.056522: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcuda.so.1
# 2021-06-09 09:00:59.094163: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-06-09 09:00:59.094771: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla T4 computeCapability: 7.5
# coreClock: 1.59GHz coreCount: 40 deviceMemorySize: 14.75GiB deviceMemoryBandwidth: 298.08GiB/s
# 2021-06-09 09:00:59.094819: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# 2021-06-09 09:00:59.113701: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublas.so.11
# 2021-06-09 09:00:59.113786: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublasLt.so.11
# 2021-06-09 09:00:59.126703: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcufft.so.10
# 2021-06-09 09:00:59.131599: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcurand.so.10
# 2021-06-09 09:00:59.141358: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcusolver.so.10
# 2021-06-09 09:00:59.148590: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcusparse.so.11
# 2021-06-09 09:00:59.152070: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudnn.so.8
# 2021-06-09 09:00:59.152229: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-06-09 09:00:59.152884: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-06-09 09:00:59.153447: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1871] Adding visible gpu devices: 0
# 2021-06-09 09:00:59.154053: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-06-09 09:00:59.154628: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla T4 computeCapability: 7.5
# coreClock: 1.59GHz coreCount: 40 deviceMemorySize: 14.75GiB deviceMemoryBandwidth: 298.08GiB/s
# 2021-06-09 09:00:59.154709: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-06-09 09:00:59.155314: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-06-09 09:00:59.155928: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1871] Adding visible gpu devices: 0
# 2021-06-09 09:00:59.156043: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# 2021-06-09 09:00:59.776573: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2021-06-09 09:00:59.776628: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]      0
# 2021-06-09 09:00:59.776650: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 0:   N
# 2021-06-09 09:00:59.776835: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-06-09 09:00:59.777523: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-06-09 09:00:59.778117: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-06-09 09:00:59.778652: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2021-06-09 09:00:59.778701: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1418] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 13837 MB memory) -> physical GPU (device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5)
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/autograph/impl/api.py:463: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with back_prop=False is deprecated and will be removed in a future version.
# Instructions for updating:
# back_prop=False is deprecated. Consider using tf.stop_gradient instead.
# Instead of:
# results = tf.map_fn(fn, elems, back_prop=False)
# Use:
# results = tf.nest.map_structure(tf.stop_gradient, tf.map_fn(fn, elems))
# W0609 09:00:59.932353 140547780331392 deprecation.py:601] From /usr/local/lib/python3.7/dist-packages/tensorflow/python/autograph/impl/api.py:463: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with back_prop=False is deprecated and will be removed in a future version.
# Instructions for updating:
# back_prop=False is deprecated. Consider using tf.stop_gradient instead.
# Instead of:
# results = tf.map_fn(fn, elems, back_prop=False)
# Use:
# results = tf.nest.map_structure(tf.stop_gradient, tf.map_fn(fn, elems))
# INFO:tensorflow:depth of additional conv before box predictor: 0
# I0609 09:01:12.372893 140547780331392 convolutional_keras_box_predictor.py:154] depth of additional conv before box predictor: 0
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:206: calling crop_and_resize_v1 (from tensorflow.python.ops.image_ops_impl) with box_ind is deprecated and will be removed in a future version.
# Instructions for updating:
# box_ind is deprecated, use box_indices instead
# W0609 09:01:18.056974 140547780331392 deprecation.py:534] From /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:206: calling crop_and_resize_v1 (from tensorflow.python.ops.image_ops_impl) with box_ind is deprecated and will be removed in a future version.
# Instructions for updating:
# box_ind is deprecated, use box_indices instead
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/autograph/impl/api.py:464: Tensor.experimental_ref (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use ref() instead.
# W0609 09:01:18.539059 140547780331392 deprecation.py:336] From /usr/local/lib/python3.7/dist-packages/tensorflow/python/autograph/impl/api.py:464: Tensor.experimental_ref (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use ref() instead.
# INFO:tensorflow:Removing rpn_box_predictor_features from prediction_dict
# I0609 09:01:22.818798 140547780331392 api.py:464] Removing rpn_box_predictor_features from prediction_dict
# INFO:tensorflow:Removing rpn_features_to_crop from prediction_dict
# I0609 09:01:22.819107 140547780331392 api.py:464] Removing rpn_features_to_crop from prediction_dict
# INFO:tensorflow:Removing feature_maps from prediction_dict
# I0609 09:01:22.819258 140547780331392 api.py:464] Removing feature_maps from prediction_dict
# 2021-06-09 09:01:23.407636: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:176] None of the MLIR Optimization Passes are enabled (registered 2)
# 2021-06-09 09:01:23.408496: I tensorflow/core/platform/profile_utils/cpu_utils.cc:114] CPU Frequency: 2199995000 Hz
# INFO:tensorflow:Removing rpn_box_predictor_features from prediction_dict
# I0609 09:01:26.669326 140547780331392 api.py:464] Removing rpn_box_predictor_features from prediction_dict
# INFO:tensorflow:Removing rpn_features_to_crop from prediction_dict
# I0609 09:01:26.669575 140547780331392 api.py:464] Removing rpn_features_to_crop from prediction_dict
# INFO:tensorflow:Removing feature_maps from prediction_dict
# I0609 09:01:26.669737 140547780331392 api.py:464] Removing feature_maps from prediction_dict
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.meta_architectures.faster_rcnn_meta_arch.FasterRCNNMetaArch object at 0x7fd372cfec90>, because it is not built.
# W0609 09:01:29.048789 140547780331392 save_impl.py:77] Skipping full serialization of Keras layer <object_detection.meta_architectures.faster_rcnn_meta_arch.FasterRCNNMetaArch object at 0x7fd372cfec90>, because it is not built.
# 2021-06-09 09:01:53.679551: W tensorflow/python/util/util.cc:348] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# INFO:tensorflow:Removing rpn_box_predictor_features from prediction_dict
# I0609 09:01:57.616050 140547780331392 api.py:464] Removing rpn_box_predictor_features from prediction_dict
# INFO:tensorflow:Removing rpn_features_to_crop from prediction_dict
# I0609 09:01:57.616313 140547780331392 api.py:464] Removing rpn_features_to_crop from prediction_dict
# INFO:tensorflow:Removing feature_maps from prediction_dict
# I0609 09:01:57.616468 140547780331392 api.py:464] Removing feature_maps from prediction_dict
# W0609 09:02:34.404804 140547780331392 save.py:243] Found untraced functions such as FirstStageBoxPredictor_layer_call_and_return_conditional_losses, FirstStageBoxPredictor_layer_call_fn, mask_rcnn_keras_box_predictor_layer_call_and_return_conditional_losses, mask_rcnn_keras_box_predictor_layer_call_fn, FirstStageBoxPredictor_layer_call_fn while saving (showing 5 of 125). These functions will not be directly callable after loading.
# WARNING:tensorflow:FOR KERAS USERS: The object that you are saving contains one or more Keras models or layers. If you are loading the SavedModel with `tf.keras.models.load_model`, continue reading (otherwise, you may ignore the following instructions). Please change your code to save with `tf.keras.models.save_model` or `model.save`, and confirm that the file "keras.metadata" exists in the export directory. In the future, Keras will only load the SavedModels that have this file. In other words, `tf.saved_model.save` will no longer write SavedModels that can be recovered as Keras models (this will apply in TF 2.5).
#
# FOR DEVS: If you are overwriting _tracking_metadata in your class, this property has been used to save metadata in the SavedModel. The metadta field will be deprecated soon, so please move the metadata to a different file.
# W0609 09:02:44.023097 140547780331392 save.py:1240] FOR KERAS USERS: The object that you are saving contains one or more Keras models or layers. If you are loading the SavedModel with `tf.keras.models.load_model`, continue reading (otherwise, you may ignore the following instructions). Please change your code to save with `tf.keras.models.save_model` or `model.save`, and confirm that the file "keras.metadata" exists in the export directory. In the future, Keras will only load the SavedModels that have this file. In other words, `tf.saved_model.save` will no longer write SavedModels that can be recovered as Keras models (this will apply in TF 2.5).
#
# FOR DEVS: If you are overwriting _tracking_metadata in your class, this property has been used to save metadata in the SavedModel. The metadta field will be deprecated soon, so please move the metadata to a different file.
# INFO:tensorflow:Assets written to: workspace/models/my_maskrcnn/inference_graph/saved_model/assets
# I0609 09:02:45.861622 140547780331392 builder_impl.py:775] Assets written to: workspace/models/my_maskrcnn/inference_graph/saved_model/assets
# INFO:tensorflow:Writing pipeline config file to workspace/models/my_maskrcnn/inference_graph/pipeline.config
# I0609 09:02:47.593521 140547780331392 config_util.py:254] Writing pipeline config file to workspace/models/my_maskrcnn/inference_graph/pipeline.config
